# %%
# Dependencies
import matplotlib.pyplot as plt
# %matplotlib inline

import os
import numpy as np
import tensorflow as tf

os.environ['KMP_DUPLICATE_LIB_OK']='True'

from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import (
    VGG19, 
    preprocess_input, 
    decode_predictions
)

# %%
# Define default image size
image_size = (224, 224)

# %% [markdown]
# VGG19

# %%
# Load the VGG19 model
# https://keras.io/api/applications/vgg/#vgg19-function
model = VGG19(include_top=True, weights='imagenet')
# Out:
# ...
# 574726144/574710816 [==============================] - 408s 1us/step

# %%
# Refactor above steps into reusable function
def predict(image_path):
    """Use VGG19 to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))

# %%
image_path = os.path.join("images", "leopard.jpg")
predict(image_path)
# Out:
# ...
# 49152/35363 [=========================================] - 0s 1us/step
# Predicted: [[('n02124075', 'Egyptian_cat', 0.68266344), ('n02128925', 'jaguar', 0.08992155), ('n02123159', 'tiger_cat', 0.07624494)]]

# %%
image_path = os.path.join("images", ".jpg")
predict(image_path)
# Out:
# Predicted: [[('n02113978', 'Mexican_hairless', 0.55920887), ('n02085620', 'Chihuahua', 0.19630359), ('n02087046', 'toy_terrier', 0.10782555)]]

# %%
image_path = os.path.join("images", "blackcat.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02124075', 'Egyptian_cat', 0.44689086), ('n02104365', 'schipperke', 0.16927756), ('n02971356', 'carton', 0.051987164)]]

# %% [markdown]
# ResNet50

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

model = ResNet50(weights='imagenet')

def predict(image_path):
    """Use ResNet50 to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))
# Out:
# ...
# 102981632/102967424 [==============================] - 34s 0us/step

# %%
image_path = os.path.join("images", "leopard.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02128925', 'jaguar', 0.5387161), ('n02128385', 'leopard', 0.08285671), ('n02124075', 'Egyptian_cat', 0.07621305)]]

# %%
image_path = os.path.join("images", "sphinx.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02113978', 'Mexican_hairless', 0.45407954), ('n02091032', 'Italian_greyhound', 0.35870907), ('n02087046', 'toy_terrier', 0.10572643)]]

# %%
image_path = os.path.join("images", "hippo.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02398521', 'hippopotamus', 0.99706525), ('n02113978', 'Mexican_hairless', 0.0016513265), ('n02454379', 'armadillo', 0.00038346642)]]

# %%
image_path = os.path.join("images", "redpanda.jpg")
predict(image_path)
# Out:
# Predicted: [[('n02509815', 'lesser_panda', 0.99692506), ('n02443114', 'polecat', 0.0025969364), ('n02441942', 'weasel', 0.00013020693)]]

# %%
image_path = os.path.join("images", "komododragon.jpg")
predict(image_path)
# Out:
# Predicted: [[('n01695060', 'Komodo_dragon', 0.9967692), ('n01677366', 'common_iguana', 0.0013886222), ('n01692333', 'Gila_monster', 0.0004035383)]]

# %% [markdown]
# Xception

# %%
# https://keras.io/api/applications/xception/
from tensorflow.keras.applications import Xception

model = Xception(include_top=True, weights='imagenet')
image_size = (299, 299)

def predict(image_path):
    """Use Xception to label image"""
    img = image.load_img(image_path, target_size=image_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    predictions = model.predict(x)
    plt.imshow(img)
    print('Predicted:', decode_predictions(predictions, top=3))
# Out:
# ...
# 91897856/91884032 [==============================] - 21s 0us/step

# %%
image_path = os.path.join("images", "komododragon.jpg")
predict(image_path)
# Out:
# Predicted: [[('n03814906', 'necklace', 0.6216878), ('n02769748', 'backpack', 0.2541091), ('n02834397', 'bib', 0.040597983)]]

# %%
image_path = os.path.join("images", "squirrel.jpg")
predict(image_path)
# Out:
# Predicted: [[('n03942813', 'ping-pong_ball', 0.997721), ('n03814906', 'necklace', 0.0019337038), ('n02769748', 'backpack', 0.0002795617)]]
